# %% [markdown]
# <a href="https://colab.research.google.com/github/zelalemf/CyberChef/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
from sqlalchemy import create_engine
import pymysql
#import pyodbc
result=pd.read_excel("sample_data/champ_web.xlsx")




#host address
hostname="54.37.57.28:3306"
#hostname="localhost"
dbname="mydatabase"
uname="root"
pwd="Servrootoot?2022"

#creating engine for connecting
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}".format(host="54.37.57.28:3306", db="mydatabase", user="root", pw="Server%Root?2022"),pool_pre_ping=True)
#engine = create_engine("mysql+pymysql://root:pw@host/db", pool_pre_ping=True)
#loading the data to sql database
result.to_sql('mydatabase', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
# !ls
# Out:
# sample_data
